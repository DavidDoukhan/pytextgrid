# %%
from pytextgrid.PraatTextGrid import PraatTextGrid

# %%
ptg = PraatTextGrid.loadfromfile('/home/ddoukhan/Desktop/radio_rtl_20121222_124500_300.TextGrid')

# %%
for i, tier in enumerate(ptg):
    print('Tier %d <%s>' % (i, tier._name))
    for intv in tier:
        print(intv)
# Out:
# Tier 0 <locuteurs>
# <intv xmin=0.000 xmax=3.759 text=>
# <intv xmin=3.759 xmax=7.472 text=>
# <intv xmin=7.472 xmax=12.236 text=L1>
# <intv xmin=12.236 xmax=13.109 text=L1L2>
# <intv xmin=13.109 xmax=23.661 text=L1>
# <intv xmin=23.661 xmax=23.852 text=L1L2>
# <intv xmin=23.852 xmax=26.072 text=L2>
# <intv xmin=26.072 xmax=26.362 text=L1L2>
# <intv xmin=26.362 xmax=29.554 text=L2>
# <intv xmin=29.554 xmax=30.010 text=L1L2>
# <intv xmin=30.010 xmax=31.915 text=L1>
# <intv xmin=31.915 xmax=36.033 text=L2>
# <intv xmin=36.033 xmax=40.127 text=L1>
# <intv xmin=40.127 xmax=40.436 text=>
# <intv xmin=40.436 xmax=45.304 text=L1>
# <intv xmin=45.304 xmax=48.691 text=L1>
# <intv xmin=48.691 xmax=49.070 text=L1L2>
# <intv xmin=49.070 xmax=49.671 text=L1>
# <intv xmin=49.671 xmax=50.997 text=L2>
# <intv xmin=50.997 xmax=51.313 text=L1L2>
# <intv xmin=51.313 xmax=58.821 text=L1>
# <intv xmin=58.821 xmax=59.384 text=>
# <intv xmin=59.384 xmax=59.767 text=L1L2>
# ...
